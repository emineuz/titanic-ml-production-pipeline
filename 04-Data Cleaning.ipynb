# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

# %%
df = pd.read_csv("titanic.csv")

# %%
df = df.loc[:, ~df.columns.str.contains("zero")]
# gereksiz kolonları silelim

# %%
df.isnull().sum()
# Out:
# Passengerid    0
# Age            0
# Fare           0
# Sex            0
# sibsp          0
# Parch          0
# Pclass         0
# Embarked       2
# 2urvived       0
# dtype: int64

# %%
df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])

# %%
df.isnull().sum()
# Out:
# Passengerid    0
# Age            0
# Fare           0
# Sex            0
# sibsp          0
# Parch          0
# Pclass         0
# Embarked       0
# 2urvived       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
Q1 = df["Fare"].quantile(0.25)
Q3 = df["Fare"].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# %%
df = pd.get_dummies(df, columns=["Embarked"], drop_first=True)

# %%
features = ["Pclass", "Sex", "Age", "Fare", "sibsp", "Parch"]
X = df[features]
y = df["2urvived"]

# %% [markdown]
# ### “Veri seti, eksik değerlerin giderilmesi, anlamsız sütunların kaldırılması ve kategorik değişkenlerin sayısallaştırılmasıyla modellemeye uygun hale getirilmiştir.”

# %%
df.to_csv("titanic_cleaned.csv", index=False)
